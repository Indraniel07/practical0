# %% [markdown]
# <a href="https://colab.research.google.com/github/Indraniel07/practical0/blob/main/EXP4.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
thisset={"apple","banana","cherry"}
print(thisset)
# Out:
# {'apple', 'cherry', 'banana'}

# %% [markdown]
# EXP4-Study of set in python
# Name=Indraniel Wandkar
# PRN=25070123156

# %%
thisset={"apple","banana","cherry"}
# print(thisset[1])  # set is not subscriptable

# %%
thisset={"apple","banana","cherry","apple"}
print(thisset)
# Out:
# {'apple', 'cherry', 'banana'}

# %%
thisset={"apple","banana","cherry",True,1,2}
print(thisset)
# Out:
# {True, 2, 'apple', 'cherry', 'banana'}

# %%
thisset={"apple","banana","cherry"}
print("banana" in thisset)
print("Grapes" in thisset)
# Out:
# True
# False

# %%
thisset={"apple","banana","cherry"}
thisset.add("orange")
print(thisset)
# Out:
# {'apple', 'orange', 'cherry', 'banana'}

# %%
thisset={"apple","banana","cherry"}
thisset.remove("banana")
print(thisset)
# Out:
# {'apple', 'cherry'}

# %% [markdown]
# SET operation

# %%
A={1,2,3,4}
B={3,4,5,6}
print("union:",A|B)
print("intersection:",A&B)
print("Difference1:",A-B)
print("Difference2:",B-A)
print("symmetric difference:",A^B)
# Out:
# union: {1, 2, 3, 4, 5, 6}
# intersection: {3, 4}
# Difference1: {1, 2}
# Difference2: {5, 6}
# symmetric difference: {1, 2, 5, 6}

# %% [markdown]
# Frozenset

# %%
x=frozenset({"apple","banana","cherry"})
print(x)
print(type(x))
# Out:
# frozenset({'apple', 'cherry', 'banana'})
# <class 'frozenset'>

# %%
studentlist={"a","b","c","d","b","c"}
studentlist=set(studentlist)
print(studentlist)
# Out:
# {'a', 'b', 'c', 'd'}

# %%
x={"Maths","Physics","Chemistry"}
y={"Biology","Physics","Chemistry"}
z={"Maths","Biology","Chemistry"}
print(x & y & z)
# Out:
# {'Chemistry'}

# %%
cricket={"Vivek","Yuvraj","Niyant"}
football={"Vivek","Glen","Vrishin"}
print(cricket & football)
print(cricket ^ football)
# Out:
# {'Vivek'}
# {'Niyant', 'Glen', 'Vrishin', 'Yuvraj'}

# %%
all_students={"Vivek","Khush","Harshit","Kshitij","Niyant","Yuvraj"}
present_students={"Vivek","Khush","Niyant"}
print(all_students-present_students)
# Out:
# {'Yuvraj', 'Kshitij', 'Harshit'}

# %%
course={"ETC101","ETC102","ETC103"}
course.discard("ETC102")
print(course)
# Out:
# {'ETC101', 'ETC103'}
