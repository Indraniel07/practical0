# %% [markdown]
# <a href="https://colab.research.google.com/github/Indraniel07/practical0/blob/main/experiment1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# Indraniel Wandkar
# 25070123167
# exp1-introduction to python

# %%
x="apple"
y="cherry"
z="orange"
print(x,y,z)
# Out:
# apple cherry orange

# %%
x,y,z="apple","banana","cherry"
print(x,y,z,sep="\n")
# Out:
# apple
# banana
# cherry

# %%
x=2
y=2.5
z="indraniel"
w=True
print(type(x),type(y),type(z),type(w))
# Out:
# <class 'int'> <class 'float'> <class 'str'> <class 'bool'>

# %%
a,b=10,5
print("sum=",a+b)

# %%
a=int(input("enter first number="))
b=int(input("enter second number="))
print("sum",a+b)
print("minus",a-b)
print("division",a/b)
print("power",a**b)
print("multiplication",a*b)
# Out:
# enter first number=4
# enter second number=6
# sum 10
# minus -2
# division 0.6666666666666666
# power 4096
# multiplication 24

# %%
#area of circle
import math
radius=float(input("enter the raidus"))
area=math.pi*(radius**2)
print("the radius of circle is=",area)
# Out:
# enter the raidus7
# the radius of circle is= 153.93804002589985

# %%
import math
x=math.log10(10)
print(x)
# Out:
# 1.0

# %%
import math
x=math.sin(45)
print(x)
# Out:
# 0.8509035245341184

# %%
a=int(input("enter first number"))
b=int(input("enter second number"))
if a>b:
  print("a is greater than b")
else:
  print("b is greater than a")
# Out:
# enter first number5
# enter second number6
# b is greater than a
