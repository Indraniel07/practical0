# %% [markdown]
# <a href="https://colab.research.google.com/github/Indraniel07/practical0/blob/main/exp3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# indraniel wandkar
# prn=25070123156
# exp3:study of tupple in python

# %%
x=(2,"indraniel",True)
print(x)
# Out:
# (2, 'indraniel', True)

# %%
tpl1=("apple","banana","orange")
print(tpl1[1])
print(tpl1[-2])
print(tpl1)
tpl1[1]="kiwi"
# Out:
# banana
# banana
# ('apple', 'banana', 'orange')
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipython-input-3209800799.py in <cell line: 0>()
#       3 print(tpl1[-2])
#       4 print(tpl1)
# ----> 5 tpl1[1]="kiwi"
#
# TypeError: 'tuple' object does not support item assignment

# %%
tpl3=(10,)*5
print(tpl3)
# Out:
# (10, 10, 10, 10, 10)

# %%
tpl4=(10)*5
print(tpl4)
# Out:
# 50

# %%
list1=["symbiosis",]*5
print(list1)
# Out:
# ['symbiosis', 'symbiosis', 'symbiosis', 'symbiosis', 'symbiosis']

# %%
tpl4=("apple","banana","orange")
print("before:",id(tpl4))
tpl5=("mango",)
tpl4+=tpl5
print(tpl4)
print("after:",id(tpl4))
# Out:
# before: 138479903620416
# ('apple', 'banana', 'orange', 'mango')
# after: 138479903059424

# %%
marks=(75,85,90,66,88)
print(max(marks))
print(min(marks))
print(sum(marks))
print(len(marks))
print(sum(marks)/len(marks))
print(sorted(marks))
print(marks)
# Out:
# 90
# 66
# 404
# 5
# 80.8
# [66, 75, 85, 88, 90]
# (75, 85, 90, 66, 88)

# %%
result=("maths",77,"A")
subject,marks,grade=result
subject,marks,grade=("maths",77,"A")
print("subject:",subject)
print("Marks:",marks)
print("grade:",grade)
if marks>=75:
  print("distinction")
else:
  print("not distinction")
# Out:
# subject: maths
# Marks: 77
# grade: A
# distinction

# %%
attandance=("A","P","A","P","A")
print("Total Present Days:",attandance.count("P"))
print("Total Absent Days:",attandance.count("A"))
if "A" in attandance:
  print("employee was absent at least once")
# Out:
# Total Present Days: 2
# Total Absent Days: 3
# employee was absent at least once

# %%
# Out:
# ''
