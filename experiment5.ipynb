# %% [markdown]
# <a href="https://colab.research.google.com/github/Indraniel07/practical0/blob/main/experiment5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# EXPERIMENT5=Dictionary in python
# Name=Indraniel Wandkar
# PRN=25070123156

# %%
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
print(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964}

# %%
thisdict = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964,
    "year": 2020,
}
print(thisdict)

len(thisdict)
# Out:
# {'brand': 'Ford', 'model': 'Mustang', 'year': 2020}
# 3

# %%
car = {
    "brand": "Ford",
    "model": "Mustang",
    "year": 1964
}
car["color"] = "red"
print(type(car))
print(car)

x = car.values()
print(x)
# Out:
# <class 'dict'>
# {'brand': 'Ford', 'model': 'Mustang', 'year': 1964, 'color': 'red'}
# dict_values(['Ford', 'Mustang', 1964, 'red'])

# %%
student = {
    "roll": 135,
    "name": "Vivek",
    "branch": "ENTC"
}
print("Name :",student["name"])

student.pop("branch")
print("After removal :", student)
# Out:
# Name : Vivek
# After removal : {'roll': 135, 'name': 'Vivek'}

# %%
products = {"pen": 10, "Book": 50, "Book": 55, "Scale": 20}
print("original Products :",products)
products["Book"] = 55
print("After update products",products)
# Out:
# original Products : {'pen': 10, 'Book': 55, 'Scale': 20}
# After update products {'pen': 10, 'Book': 55, 'Scale': 20}

# %%
marks = {"A": 85, "B": 72, "C": 90}
name = input("Enter student name: ")
print(marks.get(name, "Student not found"))

# %%
users = {"admin": '1234', "student": "abcd"}
user_name = input("username: ")
pw = input("passward: ")

if users.get(user_name) == pw :
  print("Login successful")
else :
    print("Invaid Username or password")

# %%
marks = {"A": 85, "B": 92, "C": 78}
topper = max(marks, key=marks.get)
print("Topper:", topper)
print("Marks:", marks[topper])
