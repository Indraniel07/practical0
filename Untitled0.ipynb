# %%
#PRN-25070123156
#name-Indraniel Wandkar

# %% [markdown]
# aim=to print full name in pyhon

# %%
print("indraniel wandkar")
# Out:
# indraniel wandkar

# %%
print(3280938409)
# Out:
# 3280938409

# %%
print("[1,2,5]")
# Out:
# [1,2,5]

# %%
print("indraniel wandkar",2,[1,2,5])
# Out:
# indraniel wandkar 2 [1, 2, 5]

# %%
x=2
y=[1,2,5]
z="inraniel"
print(x,y,z)
# Out:
# 2 [1, 2, 5] inraniel
