# %% [markdown]
# <a href="https://colab.research.google.com/github/Indraniel07/practical0/blob/main/exp2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Indraniel Wandkar
#25070123156

# %% [markdown]
# aim=to study list in python

# %%
list1=["apple","orange","cherry"]
print(list1)
# Out:
# ['apple', 'orange', 'cherry']

# %%
list2=[2,"indrniel",True]
print(list2)
# Out:
# [2, 'indrniel', True]

# %%
list3=["apple","banana","cherry","orange","kiwi","mango"]
print(list3[2])
print(list3[-4])
print(list3[2:5])
print(list3[:5])
print(list3[:-3])
print(list3[2:])
print(len(list3))
# Out:
# cherry
# cherry
# ['cherry', 'orange', 'kiwi']
# ['apple', 'banana', 'cherry', 'orange', 'kiwi']
# ['apple', 'banana', 'cherry']
# ['cherry', 'orange', 'kiwi', 'mango']
# 6

# %%
list4=["apple","orange","cherry"]
list4[1]="mango"
print(list4)
# Out:
# ['apple', 'mango', 'cherry']

# %%
list5=["apple","oramge","mango"]
list5.append("cherry")
print(list5)
# Out:
# ['apple', 'oramge', 'mango', 'cherry']

# %%
list6=["apple","oramge","mango"]
list6.insert(1,"mango")
print(list6)
# Out:
# ['apple', 'mango', 'oramge', 'mango']

# %%
list7=["apple","banana","orange"]
list8=["kiwi","mango","orange"]
list7.extend(list8)
print(list7)
# Out:
# ['apple', 'banana', 'orange', 'kiwi', 'mango', 'orange']

# %%
list9=["apple","orange","apple","cherry"]
print(list9)
# Out:
# ['apple', 'orange', 'apple', 'cherry']

# %%
marks=[75,85,90,66,88]
print(max(marks))
print(min(marks))
print(sum(marks))
print(len(marks))
print(sum(marks)/len(marks))
marks.sort()
print(marks)
# Out:
# 90
# 66
# 404
# 5
# 80.8
# [66, 75, 85, 88, 90]

# %%
list=["banana","protein","creatine","omega 3","whey"]
list.append("tren")
list.remove("protein")
print(list)
# Out:
# ['banana', 'creatine', 'omega 3', 'whey', 'tren']
